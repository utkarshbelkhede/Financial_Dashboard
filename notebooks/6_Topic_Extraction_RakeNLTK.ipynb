# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshbelkhede/Financial_Dashboard/blob/master/notebooks/6_Topic_Extraction_RakeNLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Working Directory
import os

os.chdir('/content/drive/MyDrive/Documents/Market Intelligence')

# %%
# !pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.7/dist-packages (from rake-nltk) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.1)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./datasets/summarized_dataframe_sshleifer_distilbart-cnn-12-6.csv")
df.head(3)
# Out:
#   Company  Year                                           Business  \
# 0    Meta  2021   Facebook's mission is to give people the powe...
# 1    Meta  2020   Facebook's mission is to give people the powe...
# 2    Meta  2019   Facebook, the Facebook logo, FB, the Like but...
#
#                                          Risk Factor  \
# 0   The persistence of COVID-19, and the preventa...
# 1   The persistence of COVID-19, and the preventa...
# 2   We cannot guarantee that the program will be ...
#
#                            Unresolved Staff Comments  \
# 0   Item 1B.  Unresolved Staff Comments None. Ite...
# 1   Item 1B.  Unresolved Staff Comments None. Ite...
# 2   Item 1B.  Unresolved Staff Comments None. Ite...
#
#                                           Properties  \
# 0   Our corporate headquarters are located in Men...
# 1   As of December 31, 2020, we owned and leased ...
# 2   As of December 31, 2019, we owned and leased ...
#
#                                    Legal Proceedings  \
# 0   Meta Platforms Ireland is subject to litigati...
# 1   Facebook Ireland challenged procedural aspect...
# 2   Multiple putative class actions and derivativ...
#
#   Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities  \
# 0   Meta Platforms, Inc. has never declared or pa...
# 1   The graph assumes that $100 was invested at t...
# 2   The board of directors has authorized a share...
#
#   Management’s Discussion and Analysis of Financial Condition and Results of Operations  \
# 0   Marketing and sales expenses in 2021 increase...
# 1   This measure may be different from nonGAAP fi...
# 2   Revenue was $70. 67 billion and $1. 34 billio...
#
#   Quantitative and Qualitative Disclosures About Market Risk  \
# 0   Our equity investments are investments in equ...
# 1   We are exposed to market risks, including cha...
# 2   Interest rates affect the interest earned on ...
#
#          Financial Statements and Supplementary Data  \
# 0   Family of Apps revenue $ 117,929  $ 85,965  $...
# 1   The following table reflects changes in the g...
# 2   The Company changed its method of accounting ...
#
#                              Controls and Procedures
# 0   There were no changes in our internal control...
# 1   There were no changes in our internal control...
# 2   Our management is responsible for establishin...

# %%
li = list(df.iloc[:,1])

# %%
from rake_nltk import Rake

# %%
r = Rake()

# %%
r.extract_keywords_from_text(df.iloc[0,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8afe9cd87246> in <module>
# ----> 1 r.extract_keywords_from_text(df.iloc[0,1])
#
# /usr/local/lib/python3.7/dist-packages/rake_nltk/rake.py in extract_keywords_from_text(self, text)
#     124         :param text: Text to extract keywords from, provided as a string.
#     125         """
# --> 126         sentences: List[Sentence] = self._tokenize_text_to_sentences(text)
#     127         self.extract_keywords_from_sentences(sentences)
#     128
#
# /usr/local/lib/python3.7/dist-packages/rake_nltk/rake.py in _tokenize_text_to_sentences(self, text)
#     178         :return: List of sentences as per the tokenizer used.
#     179         """
# --> 180         return self.sentence_tokenizer(text)
#     181
#     182     def _tokenize_sentence_to_words(self, sentence: Sentence) -> List[Word]:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1274         Given a text, returns a list of the sentences in that text.
#    1275         """
# -> 1276         return list(self.sentences_from_text(text, realign_boundaries))
#    1277
#    1278     def debug_decisions(self, text):
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1330         follows the period.
#    1331         """
# -> 1332         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1333
#    1334     def _match_potential_end_contexts(self, text):
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1330         follows the period.
#    1331         """
# -> 1332         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1333
#    1334     def _match_potential_end_contexts(self, text):
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1320         if realign_boundaries:
#    1321             slices = self._realign_boundaries(text, slices)
# -> 1322         for sentence in slices:
#    1323             yield (sentence.start, sentence.stop)
#    1324
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1419         """
#    1420         realign = 0
# -> 1421         for sentence1, sentence2 in _pair_iter(slices):
#    1422             sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1423             if not sentence2:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in _pair_iter(iterator)
#     316     iterator = iter(iterator)
#     317     try:
# --> 318         prev = next(iterator)
#     319     except StopIteration:
#     320         return
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1393     def _slices_from_text(self, text):
#    1394         last_break = 0
# -> 1395         for match, context in self._match_potential_end_contexts(text):
#    1396             if self.text_contains_sentbreak(context):
#    1397                 yield slice(last_break, match.end())
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py in _match_potential_end_contexts(self, text)
#    1373         before_words = {}
#    1374         matches = []
# -> 1375         for match in reversed(list(self._lang_vars.period_context_re().finditer(text))):
#    1376             # Ignore matches that have already been captured by matches to the right of this match
#    1377             if matches and match.end() > before_start:
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
r.get_ranked_phrases()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8b03798c8173> in <module>
# ----> 1 r.get_ranked_phrases()
#
# /usr/local/lib/python3.7/dist-packages/rake_nltk/rake.py in get_ranked_phrases(self)
#     144                  keyword string.
#     145         """
# --> 146         return self.ranked_phrases
#     147
#     148     def get_ranked_phrases_with_scores(self) -> List[Tuple[float, Sentence]]:
#
# AttributeError: 'Rake' object has no attribute 'ranked_phrases'

# %%
r.get_ranked_phrases_with_scores()
# Out:
# [(35.333333333333336, 'tax legislation provides preferential tax treatment'),
#  (34.0, 'violates european union state aid rules'),
#  (25.666666666666668, 'whether local country tax rulings'),
#  (9.0, 'preventative measures implemented'),
#  (9.0, 'multiple countries focusing'),
#  (6.0, 'european commission'),
#  (4.0, 'regulators regarding'),
#  (4.0, 'receive formal'),
#  (4.0, 'informal inquiries'),
#  (4.0, 'help limit'),
#  (4.0, 'government authorities'),
#  (4.0, 'conducted investigations'),
#  (1.0, 'spread'),
#  (1.0, 'regulations'),
#  (1.0, 'persistence'),
#  (1.0, 'operate'),
#  (1.0, 'laws'),
#  (1.0, 'impacted'),
#  (1.0, 'impact'),
#  (1.0, 'illness'),
#  (1.0, 'covid'),
#  (1.0, 'continue'),
#  (1.0, 'compliance'),
#  (1.0, 'business'),
#  (1.0, 'ability'),
#  (1.0, '19')]

# %%
r = Rake()

arr = df.iloc[:,2:].to_numpy()

for row in range(len(arr)):
  for col in range(len(arr[0])):
    r.extract_keywords_from_text(arr[row][col])
    arr[row][col] = r.get_ranked_phrases_with_scores()

temp2 = pd.DataFrame(arr, columns=df.iloc[:,2:].columns)

# %%
def topic_extraction(df, exclude_columns):

  r = Rake()
  
  temp1 = df.iloc[:,:exclude_columns]
  arr = df.iloc[:,exclude_columns:].to_numpy()
  columns=list(df.iloc[:,exclude_columns:].columns)
  
  for row in range(len(arr)):
    for col in range(len(arr[0])):
      r.extract_keywords_from_text(arr[row][col])
      arr[row][col] = r.get_ranked_phrases_with_scores()

  temp2 = pd.DataFrame(arr, columns=columns)

  return pd.concat([temp1, temp2], axis=1)

# %%
df = topic_extraction(df, exclude_columns=2)

# %%
df
# Out:
#                   Company  Year  \
# 0                    Meta  2021
# 1                    Meta  2020
# 2                    Meta  2019
# 3                    Meta  2018
# 4                    Meta  2017
# 5             Merck & Co.  2021
# 6             Merck & Co.  2020
# 7             Merck & Co.  2019
# 8             Merck & Co.  2018
# 9             Merck & Co.  2017
# 10          Alphabet Inc.  2021
# 11          Alphabet Inc.  2020
# 12          Alphabet Inc.  2019
# 13          Alphabet Inc.  2018
# 14  Microsoft Corporation  2021
# 15  Microsoft Corporation  2020
# 16  Microsoft Corporation  2019
# 17  Microsoft Corporation  2018
# 18  Microsoft Corporation  2017
# 19                 Costco  2021
# 20                 Costco  2020
# 21                 Costco  2019
# 22                 Costco  2018
# 23                 Costco  2017
# 24                 Pfizer  2021
# 25                 Pfizer  2020
# 26                 Pfizer  2019
# 27                 Pfizer  2018
# 28                 Pfizer  2017
# 29                PepsiCo  2021
# 30                PepsiCo  2020
# 31                PepsiCo  2019
# 32                PepsiCo  2018
# 33                PepsiCo  2017
# 34                 AbbVie  2021
# 35                 AbbVie  2020
# 36                 AbbVie  2019
# 37                 AbbVie  2018
# 38                 AbbVie  2017
# 39              Coca-Cola  2021
# 40              Coca-Cola  2020
# 41              Coca-Cola  2019
# 42              Coca-Cola  2018
# 43              Coca-Cola  2017
# 44             Mastercard  2021
# 45             Mastercard  2020
# 46             Mastercard  2019
# 47             Mastercard  2018
# 48             Mastercard  2017
#
#                                              Business  \
# 0   [(9.0, world closer together), (9.0, involve m...
# 1   [(9.0, world closer together), (9.0, impose di...
# 2   [(9.0, trade names appearing), (9.0, involve m...
# 3   [(9.0, world closer together), (9.0, trade nam...
# 4   [(9.0, artificial intelligence research), (4.0...
# 5   [(9.0, local agencies around), (9.0, independe...
# 6   [(25.0, orally administered soluble guanylate ...
# 7   [(36.0, fast track designation provides pharma...
# 8   [(33.5, fast track designation provides pharma...
# 9   [(16.0, large scale phase 2), (16.0, activated...
# 10  [(16.0, features like data migration), (9.0, s...
# 11  [(16.0, grow revenues beyond advertising), (14...
# 12  [(16.0, operating efficient data centers), (9....
# 13  [(9.0, propelling new ideas), (4.0, various st...
# 14  [(23.0, worlds largest corporate research orga...
# 15  [(23.5, worlds largest corporate research orga...
# 16  [(23.0, worlds largest corporate research orga...
# 17  [(23.0, worlds largest corporate research orga...
# 18  [(23.0, worlds largest corporate research orga...
# 19  [(36.0, business members may add additional ca...
# 20  [(36.0, week fiscal years ended august 30), (1...
# 21  [(25.0, 700 active stock keeping units), (9.0,...
# 22  [(25.0, net sales less merchandise costs), (16...
# 23  [(15.666666666666666, similar national brand p...
# 24  [(9.0, major products included), (9.0, every p...
# 25  [(25.0, face significantly increased generic c...
# 26  [(9.0, therachon holding ag), (9.0, stage biot...
# 27  [(22.5, pfizer recorded direct product revenue...
# 28  [(22.666666666666664, pfizer must report speci...
# 29  [(25.0, convenient food brands including cheet...
# 30  [(9.0, also important commodities), (4.0, prin...
# 31  [(9.0, also important commodities), (4.0, raw ...
# 32  [(16.0, meet changing consumer demands), (16.0...
# 33  [(16.0, climate change may result), (9.0, coul...
# 34  [(25.0, single global business segment dedicat...
# 35  [(45.0, european governments also regulate pha...
# 36  [(47.5, government generally introduces price ...
# 37  [(47.5, government generally introduces price ...
# 38  [(47.5, government generally introduces price ...
# 39  [(64.0, worlds top six nonalcoholic sparkling ...
# 40  [(16.0, branded beverage products available), ...
# 41  [(16.0, worldwide unit case volume), (9.0, uni...
# 42  [(25.0, cola may periodically consider options...
# 43  [(9.0, excluding seasonal hires), (9.0, collec...
# 44  [(4.0, internal controls), (4.0, data assets),...
# 45  [(16.0, mastercard makes payments easier), (16...
# 46  [(4.0, item 5), (4.0, item 4), (4.0, item 3), ...
# 47  [(9.0, based payment capabilities), (8.5, rapi...
# 48  [(16.0, central acquiring rules within), (9.0,...
#
#                                           Risk Factor  \
# 0   [(35.333333333333336, tax legislation provides...
# 1   [(60.66666666666667, brazilian general data pr...
# 2   [(34.5, mobile devices depend upon effective o...
# 3   [(34.5, mobile devices depend upon effective o...
# 4   [(9.0, government scrutiny applicable), (4.0, ...
# 5   [(9.0, product liability insurance), (9.0, hea...
# 6   [(9.0, product liability insurance), (9.0, hea...
# 7   [(16.0, vaccines carry unique risks), (9.0, pr...
# 8   [(13.333333333333334, party patents may preven...
# 9   [(9.0, harmful side effects), (8.0, animal hea...
# 10  [(36.0, marketable equity securities may diffe...
# 11  [(23.0, may also experience downward pressure)...
# 12  [(15.0, digital millennium copyright act), (9....
# 13  [(43.5, class c capital stock may fluctuate wi...
# 14  [(25.0, companies like us whose business), (15...
# 15  [(16.0, events could negatively impact), (15.5...
# 16  [(25.0, reduced future cash flow estimates), (...
# 17  [(23.5, catastrophic event could cause delays)...
# 18  [(23.5, catastrophic event could cause delays)...
# 19  [(33.5, backup systems would require significa...
# 20  [(23.333333333333332, senior management could ...
# 21  [(24.5, brand recognition could adversely affe...
# 22  [(47.33333333333333, key senior management cou...
# 23  [(23.666666666666664, unauthorized party may o...
# 24  [(16.0, respective consumer healthcare busines...
# 25  [(16.0, respective consumer healthcare busines...
# 26  [(9.0, two business operations), (9.0, identif...
# 27  [(9.0, identifying new compounds), (9.0, encou...
# 28  [(16.0, also seen significant competition), (1...
# 29  [(9.0, numerous evolving factors), (9.0, busin...
# 30  [(64.0, hard discounters take significant addi...
# 31  [(16.0, bottle deposit return system), (9.0, b...
# 32  [(36.0, warning requirements could reduce over...
# 33  [(31.5, take many forms including cyber extort...
# 34  [(16.0, abbvie product infringes upon), (15.5,...
# 35  [(16.0, third parties may claim), (16.0, abbvi...
# 36  [(16.0, abbvie product infringes upon), (14.33...
# 37  [(14.5, could cause actual results), (9.0, acc...
# 38  [(16.0, third parties may claim), (14.66666666...
# 39  [(8.0, evolved products depends), (4.0, weathe...
# 40  [(14.0, risk legal compliance environments), (...
# 41  [(14.0, risk legal compliance environments), (...
# 42  [(31.0, independent bottling partners operate ...
# 43  [(22.0, future restructuring activities may re...
# 44  [(25.0, risk management activities provide pro...
# 45  [(25.0, risk management activities provide pro...
# 46  [(12.1, risk factors risk factors), (9.05, ris...
# 47  [(9.0, one new law), (9.0, material adverse im...
# 48  [(23.333333333333336, existing tax laws may im...
#
#                             Unresolved Staff Comments  \
# 0   [(14.166666666666668, unresolved staff comment...
# 1   [(14.166666666666668, unresolved staff comment...
# 2   [(14.166666666666668, unresolved staff comment...
# 3   [(14.166666666666668, unresolved staff comment...
# 4   [(14.166666666666668, unresolved staff comment...
# 5   [(9.0, unresolved staff comments), (9.0, unres...
# 6   [(9.0, unresolved staff comments), (9.0, unres...
# 7   [(9.0, unresolved staff comments), (9.0, unres...
# 8   [(9.0, unresolved staff comments), (9.0, unres...
# 9   [(9.0, unresolved staff comments), (9.0, unres...
# 10  [(9.0, unresolved staff comments), (4.0, pleas...
# 11  [(9.0, unresolved staff comments), (4.0, paren...
# 12  [(9.0, unresolved staff comments), (4.0, pleas...
# 13  [(9.0, unresolved staff comments), (4.0, pleas...
# 14  [(61.0, written comments regarding sec reports...
# 15  [(29.333333333333332, written comments regardi...
# 16  [(29.333333333333332, written comments regardi...
# 17  [(38.166666666666664, written comments regardi...
# 18  [(38.166666666666664, written comments regardi...
# 19  [(9.0, unresolved staff comments), (9.0, unres...
# 20  [(9.0, unresolved staff comments), (9.0, unres...
# 21  [(9.0, unresolved staff comments), (9.0, unres...
# 22  [(9.0, unresolved staff comments), (9.0, unres...
# 23  [(9.0, unresolved staff comments), (9.0, unres...
# 24  [(9.0, individuals 5 years), (9.0, every perso...
# 25  [(25.0, face significantly increased generic c...
# 26  [(9.0, unresolved staff comments), (4.0, pleas...
# 27  [(9.0, unresolved staff comments), (4.0, pleas...
# 28  [(9.0, unresolved staff comments), (4.0, pleas...
# 29  [(9.0, written comments regarding), (9.0, issu...
# 30  [(9.0, written comments regarding), (9.0, issu...
# 31  [(17.833333333333336, unresolved staff comment...
# 32  [(17.5, unresolved staff comments remain unres...
# 33  [(9.0, written comments regarding), (9.0, issu...
# 34  [(14.5, unresolved staff comments none), (4.0,...
# 35  [(14.5, unresolved staff comments none), (4.0,...
# 36  [(4.0, first time), (4.0, december 11), (1.0, ...
# 37  [(4.0, first time), (4.0, december 11), (1.0, ...
# 38  [(4.0, first time), (4.0, december 11), (1.0, ...
# 39  [(9.0, unresolved staff comments), (4.0, pleas...
# 40  [(9.0, unresolved staff comments), (4.0, pleas...
# 41  [(9.0, unresolved staff comments), (4.0, pleas...
# 42  [(9.0, unresolved staff comments), (4.0, pleas...
# 43  [(9.0, unresolved staff comments), (4.0, pleas...
# 44  [(9.0, unresolved staff comments), (9.0, unres...
# 45  [(9.0, unresolved staff comments), (9.0, unres...
# 46  [(9.0, confidential support call), (8.5, unres...
# 47  [(9.0, unresolved staff comments), (4.0, pleas...
# 48  [(9.0, unresolved staff comments), (4.0, pleas...
#
#                                            Properties  \
# 0   [(36.0, leased approximately 10 million square...
# 1   [(36.0, leased approximately 10 million square...
# 2   [(36.0, leased approximately nine million squa...
# 3   [(36.0, leased approximately six million squar...
# 4   [(33.0, leased approximately three million squ...
# 5   [(9.0, mercks manufacturing operations), (9.0,...
# 6   [(9.0, mercks manufacturing operations), (9.0,...
# 7   [(16.0, disclosed capital expansion projects),...
# 8   [(9.0, mercks manufacturing operations), (8.5,...
# 9   [(24.0, mercks animal health global headquarte...
# 10  [(9.0, rd sites around), (4.0, south america),...
# 11  [(9.0, development sites around), (4.0, south ...
# 12  [(9.0, development sites around), (4.0, south ...
# 13  [(9.0, leases data centers), (9.0, development...
# 14  [(23.5, largest owned properties include space...
# 15  [(24.0, largest owned properties include space...
# 16  [(15.0, largest owned properties include), (5....
# 17  [(7.5, lease facilities internationally), (4.5...
# 18  [(7.5, lease facilities internationally), (4.5...
# 19  [(16.0, total square feet associated), (15.0, ...
# 20  [(16.0, warehouses contained approximately 116...
# 21  [(25.0, warehouses contained approximately 113...
# 22  [(23.5, following schedule shows warehouse ope...
# 23  [(23.5, following schedule shows warehouse ope...
# 24  [(25.0, approximately 41 million square feet),...
# 25  [(25.0, approximately 43 million square feet),...
# 26  [(24.0, approximately 47 million square feet),...
# 27  [(25.0, approximately 53 million square feet),...
# 28  [(16.0, surplus real property assets), (16.0, ...
# 29  [(15.0, principal executive office located), (...
# 30  [(15.0, principal executive office located), (...
# 31  [(9.0, good operating condition), (9.0, divisi...
# 32  [(9.0, good operating condition), (9.0, divisi...
# 33  [(9.0, nab latin america), (8.0, division util...
# 34  [(25.0, approximately 20 million square feet),...
# 35  [(16.0, two central distribution centers), (15...
# 36  [(15.0, 1 north waukegan road), (9.0, one dist...
# 37  [(15.0, 1 north waukegan road), (9.0, one dist...
# 38  [(15.0, 1 north waukegan road), (9.0, one dist...
# 39  [(42.25, production facilities varies based up...
# 40  [(44.0, production facilities varies based upo...
# 41  [(34.5, facilities varies based upon seasonal ...
# 42  [(33.333333333333336, facilities varies based ...
# 43  [(33.5, facilities varies based upon seasonal ...
# 44  [(16.0, leased commercial properties throughou...
# 45  [(16.0, leased commercial properties throughou...
# 46  [(4.625, property property properties), (4.0, ...
# 47  [(16.0, leased 169 commercial properties), (9....
# 48  [(13.333333333333334, leased 167 commercial pr...
#
#                                     Legal Proceedings  \
# 0   [(16.0, proceedings involving law enforcement)...
# 1   [(25.0, facebook ireland challenged procedural...
# 2   [(15.0, multiple putative class actions), (5.0...
# 3   [(16.0, two putative class actions), (9.0, off...
# 4   [(14.25, nasdaq stock market llc), (14.1666666...
# 5   [(4.0, supplementary data), (4.0, note 11), (4...
# 6   [(4.0, supplementary data), (4.0, supplementar...
# 7   [(4.0, supplementary data), (4.0, supplementar...
# 8   [(4.0, supplementary data), (4.0, note 11), (4...
# 9   [(4.0, supplementary data), (4.0, note 11), (4...
# 10  [(16.0, consolidated financial statements incl...
# 11  [(16.0, consolidated financial statements incl...
# 12  [(23.5, please see note 10 commitments), (14.5...
# 13  [(25.0, please see note 9 commitments), (14.66...
# 14  [(13.333333333333332, information regarding le...
# 15  [(16.0, companys antitrust compliance office),...
# 16  [(16.0, information regarding legal proceeding...
# 17  [(16.0, companys antitrust compliance office),...
# 18  [(16.0, companys antitrust compliance office),...
# 19  [(16.0, consolidated financial statements incl...
# 20  [(16.0, consolidated financial statements incl...
# 21  [(14.0, consolidated financial statements incl...
# 22  [(14.0, consolidated financial statements incl...
# 23  [(14.0, consolidated financial statements incl...
# 24  [(14.666666666666666, pfizer executive leaders...
# 25  [(15.0, pfizer executive leadership team), (9....
# 26  [(23.666666666666664, consolidated financial s...
# 27  [(24.0, consolidated financial statements note...
# 28  [(24.0, consolidated financial statements note...
# 29  [(15.0, see also item 1), (9.0, material adver...
# 30  [(15.0, see also item 1), (9.0, material adver...
# 31  [(15.0, see also item 1), (9.0, material adver...
# 32  [(13.833333333333334, environmental authority ...
# 33  [(16.0, supreme administrative court issued), ...
# 34  [(14.0, consolidated financial statements incl...
# 35  [(14.0, consolidated financial statements incl...
# 36  [(14.0, consolidated financial statements incl...
# 37  [(14.0, consolidated financial statements incl...
# 38  [(14.0, consolidated financial statements incl...
# 39  [(23.0, companys income taxes going forward), ...
# 40  [(14.5, wisconsin insurance coverage litigatio...
# 41  [(15.0, certain related foreign licensees), (1...
# 42  [(16.0, 000 active claims pending), (9.0, tax ...
# 43  [(15.0, wisconsin trial court entered), (15.0,...
# 44  [(16.0, consolidated financial statements incl...
# 45  [(16.0, consolidated financial statements incl...
# 46  [(9.0, next two weeks), (4.0, legal proceeding...
# 47  [(15.0, consolidated financial statements incl...
# 48  [(16.0, consolidated financial statements incl...
#
#    Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities  \
# 0   [(15.0, nasdaq global select market), (9.0, si...
# 1   [(25.0, fiscal year ended december 31), (9.0, ...
# 2   [(9.0, shares repurchased depend), (8.0, share...
# 3   [(11.733333333333333, future stock price perfo...
# 4   [(16.0, nasdaq global select market), (14.3333...
# 5   [(9.0, sp 500 index), (9.0, following graph as...
# 6   [(25.0, three months ended december 31), (15.5...
# 7   [(9.0, performance graph assumes), (9.0, compo...
# 8   [(9.0, roche holding ag), (9.0, mercks common ...
# 9   [(16.0, directors authorized additional purcha...
# 10  [(9.0, suggest future performance), (4.0, term...
# 11  [(25.0, symbol goog since august 19), (16.0, n...
# 12  [(15.5, year total shareholder return), (15.0,...
# 13  [(16.0, class c capital stock), (9.0, suggest ...
# 14  [(25.0, settle employee tax withholding relate...
# 15  [(25.0, settle employee tax withholding relate...
# 16  [(8.0, fiscal year 2020), (4.0, share repurcha...
# 17  [(25.0, settle employee tax withholding relate...
# 18  [(25.0, settle employee tax withholding relate...
# 19  [(81.0, following graph provides information c...
# 20  [(16.0, cumulative total shareholder return), ...
# 21  [(16.0, cumulative total shareholder return), ...
# 22  [(16.0, total retail market performance), (16....
# 23  [(9.0, 000 authorization approved), (4.0, repu...
# 24  [(9.0, sp 500 index), (9.0, following graph as...
# 25  [(8.0, myers squibb company), (7.5, pfizer com...
# 26  [(25.0, peer group performance graph sections)...
# 27  [(16.0, satisfy tax withholding obligations), ...
# 28  [(16.833333333333336, october 2014 stock purch...
# 29  [(42.33333333333333, paid consecutive quarterl...
# 30  [(46.5, paid consecutive quarterly cash divide...
# 31  [(15.0, nasdaq global select market), (9.0, si...
# 32  [(16.0, publicly announced repurchase programs...
# 33  [(15.0, blank check preferred stock), (9.0, ne...
# 34  [(16.0, depend upon many factors), (15.0, new ...
# 35  [(15.5, depend upon many factors), (13.5, futu...
# 36  [(9.0, securities exchange act), (4.0, section...
# 37  [(16.0, depend upon many factors), (9.0, secur...
# 38  [(15.5, depend upon many factors), (9.5, facto...
# 39  [(9.0, total shareowner return), (9.0, dow jon...
# 40  [(16.0, principal united states market), (14.6...
# 41  [(87.5, sp 500 index total return stock price ...
# 42  [(23.0, plan (" 2012 plan ")), (16.0, year end...
# 43  [(23.0, plan (" 2012 plan ")), (23.0, dow jone...
# 44  [(16.0, 49 per share paid), (12.5, class b com...
# 45  [(16.0, cumulative total stockholder return), ...
# 46  [(15.5, new york stock exchange), (9.5, common...
# 47  [(16.0, cumulative total stockholder return), ...
# 48  [(21.0, voting class b common stock), (16.0, n...
#
#    Management’s Discussion and Analysis of Financial Condition and Results of Operations  \
# 0   [(9.0, remains highly uncertain), (4.0, user g...
# 1   [(16.0, nongaap financial measures used), (9.0...
# 2   [(16.0, nongaap financial measures used), (14....
# 3   [(14.5, net unrecognized tax benefits), (9.5, ...
# 4   [(16.0, year ended december 31), (16.0, worldw...
# 5   [(49.0, publicly traded company named organon ...
# 6   [(25.0, pharmaceutical segment profits grew 5)...
# 7   [(45.0, isentress hd also partially offset rev...
# 8   [(9.0, primary peritoneal cancer), (9.0, help ...
# 9   [(9.0, united states reflecting), (9.0, public...
# 10  [(9.0, google cloud revenues), (9.0, 2021 prim...
# 11  [(34.5, search partners infringed european com...
# 12  [(16.0, corporate legal entity structure), (9....
# 13  [(15.0, accrued performance fees related), (9....
# 14  [(22.0, cloud services revenue increased 11), ...
# 15  [(21.5, microsoft 365 consumer subscription re...
# 16  [(59.0, xbox hardware revenue declined 31 %, p...
# 17  [(19.666666666666668, linkedin revenue increas...
# 18  [(19.666666666666668, linkedin revenue increas...
# 19  [(16.0, core merchandise categories increased)...
# 20  [(25.0, lower gross margin percentage relative...
# 21  [(22.0, fiscal year contractual obligations 20...
# 22  [(9.0, cash flow provided), (8.0, annual fee i...
# 23  [(25.0, income taxes requires significant judg...
# 24  [(16.0, positive nsclc approved mar), (16.0, i...
# 25  [(49.0, international operational growth /( de...
# 26  [(9.0, management management reports), (9.0, h...
# 27  [(9.0, management management reports), (8.6, 2...
# 28  [(8.666666666666666, year financial report), (...
# 29  [(9.0, tax cash proceeds), (9.0, notes due 202...
# 30  [(16.0, time mandatory transition tax), (9.0, ...
# 31  [(15.0, consolidated financial statements refe...
# 32  [(9.0, operating profit excluding), (9.0, cons...
# 33  [(45.0, higher commodity inflation reduced ope...
# 34  [(23.0, pipeline includes approximately 90 com...
# 35  [(25.0, commercialize investigational bispecif...
# 36  [(16.0, supplemental new drug application), (1...
# 37  [(16.0, worldwide net revenues grew), (16.0, h...
# 38  [(16.0, intangible asset impairment charge), (...
# 39  [(49.0, top six nonalcoholic sparkling soft dr...
# 40  [(564.5, 2 latin america 29 1 north america 37...
# 41  [(19.0, sports drinks grew 1 percent), (10.0, ...
# 42  [(16.0, two local franchise bottlers), (13.5, ...
# 43  [(25.0, deferred income taxes decreased due), ...
# 44  [(16.0, lower effective tax rates), (9.0, favo...
# 45  [(9.0, spread rapidly across), (9.0, significa...
# 46  [(25.0, local currency basis increased 13), (1...
# 47  [(16.0, net revenue increased 20), (9.0, provi...
# 48  [(25.0, adjusted operating expenses increased ...
#
#    Quantitative and Qualitative Disclosures About Market Risk  \
# 0   [(49.0, held companies without readily determi...
# 1   [(16.0, financial markets could result), (15.3...
# 2   [(9.0, foreign currency losses), (8.0, interes...
# 3   [(16.0, effect hedging activities would), (15....
# 4   [(16.0, foreign currency risks related), (15.0...
# 5   [(23.0, financial instruments market risk disc...
# 6   [(20.5, financial instruments market risk disc...
# 7   [(22.166666666666664, financial instruments ma...
# 8   [(22.166666666666664, financial instruments ma...
# 9   [(22.166666666666664, financial instruments ma...
# 10  [(25.0, foreign currency exchange rate change)...
# 11  [(36.0, impairment assessment requires signifi...
# 12  [(15.333333333333332, foreign currency gains r...
# 13  [(23.0, foreign currency spot rate changes), (...
# 14  [(16.0, following table sets forth), (9.0, inc...
# 15  [(16.0, following table sets forth), (14.66666...
# 16  [(16.0, following table sets forth), (14.66666...
# 17  [(16.0, following table sets forth), (9.0, use...
# 18  [(16.0, following table sets forth), (9.0, use...
# 19  [(16.0, known future expenditures denominated)...
# 20  [(16.0, financial market risk results), (15.0,...
# 21  [(16.0, known future expenditures denominated)...
# 22  [(16.0, known future expenditures denominated)...
# 23  [(16.0, manage counterparty risk associated), ...
# 24  [(22.0, market risk section within mda), (9.0,...
# 25  [(36.0, market risk section within mda section...
# 26  [(15.0, foreign exchange rate movements), (14....
# 27  [(16.0, may affect future results), (16.0, may...
# 28  [(16.0, may affect future results), (15.333333...
# 29  [(4.0, qualitative disclosures), (4.0, qualita...
# 30  [(4.0, qualitative disclosures), (4.0, qualita...
# 31  [(4.0, qualitative disclosures), (4.0, qualita...
# 32  [(4.0, qualitative disclosures), (4.0, qualita...
# 33  [(4.0, qualitative disclosures), (4.0, qualita...
# 34  [(34.0, 100 basis points would adversely impac...
# 35  [(24.0, primary net foreign currency exposures...
# 36  [(24.0, primary net foreign currency exposures...
# 37  [(34.0, 100 basis points would adversely impac...
# 38  [(24.5, primary net foreign currency exposures...
# 39  [(22.666666666666664, company uses derivative ...
# 40  [(23.0, company uses derivative financial inst...
# 41  [(64.0, financial market risks using several o...
# 42  [(23.5, company uses derivative financial inst...
# 43  [(33.0, derivative instruments expire within 2...
# 44  [(21.166666666666664, market risk sensitive in...
# 45  [(20.333333333333336, market risk sensitive in...
# 46  [(23.666666666666664, foreign exchange rates c...
# 47  [(30.0, also use foreign currency denominated ...
# 48  [(9.0, european foreign operations), (9.0, com...
#
#           Financial Statements and Supplementary Data  \
# 0   [(8.0, reality labs revenue), (4.0, see legal)...
# 1   [(43.0, millions ): gross unrecognized tax ben...
# 2   [(11.833333333333334, class b common stock), (...
# 3   [(16.0, year ended december 31), (16.0, compan...
# 4   [(16.0, companys financial statements based), ...
# 5   [(22.5, certain additional matters including g...
# 6   [(22.5, certain additional matters including g...
# 7   [(16.0, projected future cash flows), (16.0, i...
# 8   [(16.0, projected future cash flows), (16.0, i...
# 9   [(25.0, company may recognize additional non),...
# 10  [(25.0, following table presents revenues disa...
# 11  [(23.333333333333336, income tax audits primar...
# 12  [(23.333333333333336, income tax audits primar...
# 13  [(25.0, state net operating loss carryforwards...
# 14  [(16.0, employees may purchase shares), (9.0, ...
# 15  [(16.0, filed supplemental expert evidence), (...
# 16  [(15.0, consolidated financial statements sinc...
# 17  [(13.666666666666666, consolidated financial s...
# 18  [(13.666666666666666, consolidated financial s...
# 19  [(24.5, former temporary staffing employee fil...
# 20  [(16.0, produce high sales volumes), (16.0, op...
# 21  [(8.0, effective internal control), (5.0, inte...
# 22  [(25.0, accompanying condensed consolidated ba...
# 23  [(25.0, public company accounting oversight bo...
# 24  [(45.0, 2021 primarily include employee termin...
# 25  [(14.8, variable lease payments amounted), (14...
# 26  [(23.666666666666668, independent registered p...
# 27  [(25.0, independent registered public accounti...
# 28  [(25.0, independent registered public accounti...
# 29  [(8.266666666666666, see item 8), (8.266666666...
# 30  [(15.0, consolidated financial statements incl...
# 31  [(8.266666666666666, see item 8), (8.266666666...
# 32  [(8.266666666666666, see item 8), (8.266666666...
# 33  [(8.266666666666666, see item 8), (8.266666666...
# 34  [(16.0, stemcentrx impairment related expenses...
# 35  [(9.0, total net revenues), (9.0, term loan co...
# 36  [(16.0, actual results may differ), (9.0, trea...
# 37  [(25.0, testosterone replacement therapy produ...
# 38  [(9.0, performance shares vested), (8.5, fair ...
# 39  [(33.5, equally weighted among net operating r...
# 40  [(16.0, fair value disclosures related), (9.0,...
# 41  [(25.0, accurately predict future cash flows),...
# 42  [(25.0, accurately predict future cash flows),...
# 43  [(24.5, total unrecognized compensation cost r...
# 44  [(22.5, purported merchant class plaintiffs fi...
# 45  [(34.0, company declared total per share divid...
# 46  [(9.0, monte carlo technique), (8.5, underlyin...
# 47  [(9.0, exercise significant influence), (9.0, ...
# 48  [(9.0, measuring fair value), (9.0, level 3 du...
#
#                               Controls and Procedures
# 0   [(8.0, financial reporting identified), (5.0, ...
# 1   [(8.0, financial reporting identified), (5.0, ...
# 2   [(13.333333333333332, maintaining adequate int...
# 3   [(13.666666666666666, maintaining adequate int...
# 4   [(9.0, financial reporting based), (9.0, crite...
# 5   [(25.0, independent registered public accounti...
# 6   [(25.0, independent registered public accounti...
# 7   [(16.0, maintaining adequate internal control)...
# 8   [(25.0, independent registered public accounti...
# 9   [(25.0, independent registered public accounti...
# 10  [(15.0, quarter ended december 31), (9.0, glob...
# 11  [(25.0, independent registered public accounti...
# 12  [(16.0, quarter ended december 31), (16.0, new...
# 13  [(16.0, quarter ended december 31), (12.666666...
# 14  [(25.0, provide reasonable assurance regarding...
# 15  [(13.5, maintaining effective internal control...
# 16  [(15.5, deloite touches llp believes), (13.666...
# 17  [(16.0, accounting principles generally accept...
# 18  [(16.0, accounting principles generally accept...
# 19  [(14.0, maintaining adequate internal control)...
# 20  [(16.0, provide reasonable assurance regarding...
# 21  [(15.0, maintaining adequate internal control)...
# 22  [(8.5, interim financial statements), (4.5, fi...
# 23  [(16.0, provide reasonable assurance regarding...
# 24  [(13.600000000000001, maintaining effective in...
# 25  [(23.5, management used criteria set forth), (...
# 26  [(12.916666666666666, financial reporting mana...
# 27  [(12.916666666666666, financial reporting mana...
# 28  [(12.916666666666666, financial reporting mana...
# 29  [(25.0, ongoing global business transformation...
# 30  [(23.0, net revenue represented approximately ...
# 31  [(15.0, consolidated financial statements incl...
# 32  [(25.0, net revenue represented approximately ...
# 33  [(25.0, independent registered public accounti...
# 34  [(25.0, independent registered public accounti...
# 35  [(23.5, provide reasonable assurance regarding...
# 36  [(9.0, chief executive officer), (7.5, interna...
# 37  [(23.0, provide reasonable assurance regarding...
# 38  [(24.5, independent registered public accounti...
# 39  [(25.0, independent registered public accounti...
# 40  [(16.0, quarter ended december 31), (4.0, reas...
# 41  [(14.0, quarter ended december 31), (14.0, chi...
# 42  [(16.0, quarter ended december 31), (4.0, peri...
# 43  [(25.0, cola beverages africa proprietary limi...
# 44  [(25.0, independent registered public accounti...
# 45  [(25.0, independent registered public accounti...
# 46  [(25.0, independent registered public accounti...
# 47  [(25.0, independent registered public accounti...
# 48  [(25.0, independent registered public accounti...

# %%
df.to_csv('./datasets/topic_extraction_rakeNLTK.csv', index=False)

# %%
df.iloc[0,2][0][1]
# Out:
# 'world closer together'

# %%
import re

# %%
str = "xyz@gmail.com, utka@gmail.com, My company name is Google and it has product gmail."

print(re.sub("gmail", "yahoo", str))
# Out:
# xyz@yahoo.com, utka@yahoo.com, My company name is Google and it has product yahoo.

# %%
summary_words = re.split("(?:(?:[^a-zA-Z]+')|(?:'[^a-zA-Z]+))|(?:[^a-zA-Z']+)", summary_result.loc[summary_result.index[0], co
background = "#EAEA7F"
#background = "#FFFF
dom = []
for words in summary_words:
    if words != " ":
        dom.append(str(
            span(
                style=styles(
                    background=background,
                    border_radius=rem(0.33),
                    padding=(rem(0.125), rem(0.145)),
                    overflow="hidden",
                ))(
                words
            )
      
#st.write(dom)
listToStr = ''.join([str(elem) for elem in dom if elem != '
#st.write(listToStr)
#st.markdown("<p style='text-align: justify;>" + listToStr + "</p>", unsafe_allow_html=True)
